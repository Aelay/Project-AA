# %%
# just run all these cells,

# %%
print ("""
# first thing you need to do is get access tokens from twitter, 
# go to https://apps.twitter.com, create an app, create API access token,
# then fill out tokens.txt file in directory where .ipynb is sitting
# dont add tokens.txt file to git. leave it untracked. 
# (smart people in the internet say NEVER SHARE KEYS, never commit them to github and stuff)""")

with open('tokens.txt','w') as fout:
    fout.write('Consumer key\n')
    fout.write('Consumer secret\n')
    fout.write('token key\n')
    fout.write('token secret\n')
# Out:
# # first thing you need to do is get access tokens from twitter,
# # go to https://apps.twitter.com, create an app, create API access token,
# # then fill out tokens.txt file in directory where .ipynb is sitting
# # dont add tokens.txt file to git. leave it untracked.
# # (smart people in the internet say NEVER SHARE KEYS, never commit them to github and stuff)

# %%
import os
import hashlib

try: # i out my tokens into ENV variables, cuz that seems to be the practice,
     # if use stuff like that -- use it, if no, just use the tokens.txt file, ignore this code 
    consumer_key = os.environ['TWITTER_CONSUMER_KEY']
    consumer_secret = os.environ['TWITTER_CONSUMER_SECRET']
    token_key = os.environ['TWITTER_TOKENCS506_KEY']
    token_secret = os.environ['TWITTER_TOKENCS506_SECRET']
    print('Line1')
    
except:
    with open('tokens.txt','r') as fin:

        consumer_key = fin.readline()[:-1].encode('utf-8')
        consumer_secret = fin.readline().rstrip().encode('utf-8')
        token_key = fin.readline()[:-1].encode('utf-8')
        token_secret = fin.readline().rstrip().encode('utf-8')
# Out:
# Line1

# %% [markdown]
# ---

# %%
# our first attept from GSU, get your home page 
# if you repeat this cell several times, it's easy to get banned
import oauth2
import json

def oauth_req(url, key, secret, http_method="GET", post_body="", http_headers=None):
    consumer = oauth2.Consumer(key=consumer_key, secret=consumer_secret)
    token = oauth2.Token(key=key, secret=secret)
    client = oauth2.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers )
    return content

home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', token_key, token_secret)

content = json.loads(home_timeline)
content[:10]

# for key in content[0]:
#     print key, content[key]
    
# print content[0].items()


# output = json.dumps(home_timeline)
# print output
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 21:40:48 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2oAiqHL',
#      u'expanded_url': u'http://tcrn.ch/2oAiqHL',
#      u'indices': [26, 49],
#      u'url': u'https://t.co/lDKlRq3ali'}],
#    u'user_mentions': [{u'id': 1454021,
#      u'id_str': u'1454021',
#      u'indices': [53, 66],
#      u'name': u'Steve Gillmor',
#      u'screen_name': u'stevegillmor'}]},
#   u'favorite_count': 2,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855899210343997440,
#   u'id_str': u'855899210343997440',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'source': u'<a href="http://10up.com" rel="nofollow">10up Publish Tweet</a>',
#   u'text': u'Gillmor Gang: Fossil Fuel https://t.co/lDKlRq3ali by @stevegillmor',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1925,
#    u'follow_request_sent': False,
#    u'followers_count': 8949230,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108984,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154543,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 21:30:33 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/HCcsr0ZnKl',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855896631861837824/video/1',
#      u'id': 855896540224692224,
#      u'id_str': u'855896540224692224',
#      u'indices': [84, 107],
#      u'media_url': u'http://pbs.twimg.com/media/C-DBciCUMAEISEJ.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C-DBciCUMAEISEJ.jpg',
#      u'sizes': {u'large': {u'h': 720, u'resize': u'fit', u'w': 1280},
#       u'medium': {u'h': 675, u'resize': u'fit', u'w': 1200},
#       u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/HCcsr0ZnKl'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2po5862',
#      u'expanded_url': u'http://tcrn.ch/2po5862',
#      u'indices': [60, 83],
#      u'url': u'https://t.co/tmylN7LZOw'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'additional_media_info': {u'call_to_actions': {u'visit_site': {u'url': u'http://www.techcrunch.com/video'}},
#       u'description': u'Follow @TechCrunch',
#       u'embeddable': True,
#       u'monetizable': True,
#       u'title': u'Submersible Drone'},
#      u'display_url': u'pic.twitter.com/HCcsr0ZnKl',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855896631861837824/video/1',
#      u'id': 855896540224692224,
#      u'id_str': u'855896540224692224',
#      u'indices': [84, 107],
#      u'media_url': u'http://pbs.twimg.com/media/C-DBciCUMAEISEJ.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C-DBciCUMAEISEJ.jpg',
#      u'sizes': {u'large': {u'h': 720, u'resize': u'fit', u'w': 1280},
#       u'medium': {u'h': 675, u'resize': u'fit', u'w': 1200},
#       u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'video',
#      u'url': u'https://t.co/HCcsr0ZnKl',
#      u'video_info': {u'aspect_ratio': [16, 9],
#       u'duration_millis': 35869,
#       u'variants': [{u'bitrate': 320000,
#         u'content_type': u'video/mp4',
#         u'url': u'https://video.twimg.com/amplify_video/855896540224692224/vid/320x180/SsCkyTZ87uHmKOjG.mp4'},
#        {u'content_type': u'application/x-mpegURL',
#         u'url': u'https://video.twimg.com/amplify_video/855896540224692224/pl/_8aeTY6fSK3-x0FP.m3u8'},
#        {u'bitrate': 2176000,
#         u'content_type': u'video/mp4',
#         u'url': u'https://video.twimg.com/amplify_video/855896540224692224/vid/1280x720/F4o_3JSavXtXUXtu.mp4'},
#        {u'bitrate': 832000,
#         u'content_type': u'video/mp4',
#         u'url': u'https://video.twimg.com/amplify_video/855896540224692224/vid/640x360/Lazi6V7_wSkNMScK.mp4'}]}}]},
#   u'favorite_count': 36,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855896631861837824,
#   u'id_str': u'855896631861837824',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 28,
#   u'retweeted': False,
#   u'source': u'<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#   u'text': u'PowerRay is an underwater drone for filmmakers or\xa0fishermen https://t.co/tmylN7LZOw https://t.co/HCcsr0ZnKl',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1925,
#    u'follow_request_sent': False,
#    u'followers_count': 8949230,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108984,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154543,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 20:30:16 +0000 2017',
#   u'entities': {u'hashtags': [{u'indices': [0, 8], u'text': u'Bullish'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'snappytv.com/tc/4479047/281\u2026',
#      u'expanded_url': u'http://www.snappytv.com/tc/4479047/2817272',
#      u'indices': [37, 60],
#      u'url': u'https://t.co/CTEeEeR9uu'}],
#    u'user_mentions': []},
#   u'favorite_count': 35,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855881459071983616,
#   u'id_str': u'855881459071983616',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 28,
#   u'retweeted': False,
#   u'source': u'<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#   u'text': u'#Bullish: Tech tackles homelessness  https://t.co/CTEeEeR9uu',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1925,
#    u'follow_request_sent': False,
#    u'followers_count': 8949230,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108984,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154543,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 20:26:08 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'sciencealert.com/nasa-just-made\u2026',
#      u'expanded_url': u'http://www.sciencealert.com/nasa-just-made-all-the-scientific-research-it-funds-available-for-free#.WPu2BSILuJQ.twitter',
#      u'indices': [92, 115],
#      u'url': u'https://t.co/farQveVy8Q'}],
#    u'user_mentions': [{u'id': 76982816,
#      u'id_str': u'76982816',
#      u'indices': [3, 19],
#      u'name': u'Chanuki Seresinhe',
#      u'screen_name': u'thoughtsymmetry'},
#     {u'id': 60813201,
#      u'id_str': u'60813201',
#      u'indices': [120, 133],
#      u'name': u'ScienceAlert',
#      u'screen_name': u'ScienceAlert'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855880421581635584,
#   u'id_str': u'855880421581635584',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 1,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 19:59:04 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'sciencealert.com/nasa-just-made\u2026',
#       u'expanded_url': u'http://www.sciencealert.com/nasa-just-made-all-the-scientific-research-it-funds-available-for-free#.WPu2BSILuJQ.twitter',
#       u'indices': [71, 94],
#       u'url': u'https://t.co/farQveVy8Q'}],
#     u'user_mentions': [{u'id': 60813201,
#       u'id_str': u'60813201',
#       u'indices': [99, 112],
#       u'name': u'ScienceAlert',
#       u'screen_name': u'ScienceAlert'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855873610312974341,
#    u'id_str': u'855873610312974341',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 1,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'NASA Just Made All the Scientific Research It Funds Available for Free https://t.co/farQveVy8Q via @ScienceAlert',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Sep 24 16:41:38 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'After 10+ years in digital design, undertaking PhD in #DataScience at WBS, University of Warwick. Spending a year researching at the Alan Turing Institute.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'thoughtsymmetry.com',
#         u'expanded_url': u'http://www.thoughtsymmetry.com/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/y9h7e1Yiyg'}]}},
#     u'favourites_count': 651,
#     u'follow_request_sent': False,
#     u'followers_count': 1049,
#     u'following': False,
#     u'friends_count': 1352,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 76982816,
#     u'id_str': u'76982816',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 118,
#     u'location': u'London, United Kingdom',
#     u'name': u'Chanuki Seresinhe',
#     u'notifications': False,
#     u'profile_background_color': u'D6DFE3',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/39632479/birds.jpg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/39632479/birds.jpg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/76982816/1401460348',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/472384316362608641/k6u-Q6kW_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/472384316362608641/k6u-Q6kW_normal.jpeg',
#     u'profile_link_color': u'A01F5C',
#     u'profile_sidebar_border_color': u'EEEEEE',
#     u'profile_sidebar_fill_color': u'EFEFEF',
#     u'profile_text_color': u'636363',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'thoughtsymmetry',
#     u'statuses_count': 1197,
#     u'time_zone': u'London',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/y9h7e1Yiyg',
#     u'utc_offset': 3600,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'RT @thoughtsymmetry: NASA Just Made All the Scientific Research It Funds Available for Free https://t.co/farQveVy8Q via @ScienceAlert',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Jan 29 00:05:04 +0000 2014',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Assistant Professor of Marketing @USCMarshall. Runner, Biker, Food Lover.',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'cs-people.bu.edu/dproserp/',
#        u'expanded_url': u'http://cs-people.bu.edu/dproserp/',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/U4Wr61hYUF'}]}},
#    u'favourites_count': 26,
#    u'follow_request_sent': False,
#    u'followers_count': 263,
#    u'following': True,
#    u'friends_count': 297,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 2316238513,
#    u'id_str': u'2316238513',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 52,
#    u'location': u'Los Angeles, CA',
#    u'name': u'Davide Proserpio',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2316238513/1398357711',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/604464126593798144/cKwhIyXF_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/604464126593798144/cKwhIyXF_normal.jpg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'dade_us',
#    u'statuses_count': 2150,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'http://t.co/U4Wr61hYUF',
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 20:09:18 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/naval/status/8\u2026',
#      u'expanded_url': u'https://twitter.com/naval/status/855865123973382144',
#      u'indices': [75, 98],
#      u'url': u'https://t.co/uQZMUAVddI'}],
#    u'user_mentions': [{u'id': 38743751,
#      u'id_str': u'38743751',
#      u'indices': [3, 16],
#      u'name': u'Rob Majteles',
#      u'screen_name': u'treehcapital'},
#     {u'id': 745273,
#      u'id_str': u'745273',
#      u'indices': [68, 74],
#      u'name': u'Naval Ravikant',
#      u'screen_name': u'naval'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855876183308640256,
#   u'id_str': u'855876183308640256',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'quoted_status_id': 855865123973382144,
#   u'quoted_status_id_str': u'855865123973382144',
#   u'retweet_count': 20,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 20:04:20 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/naval/status/8\u2026',
#       u'expanded_url': u'https://twitter.com/naval/status/855865123973382144',
#       u'indices': [57, 80],
#       u'url': u'https://t.co/uQZMUAVddI'}],
#     u'user_mentions': [{u'id': 745273,
#       u'id_str': u'745273',
#       u'indices': [50, 56],
#       u'name': u'Naval Ravikant',
#       u'screen_name': u'naval'}]},
#    u'favorite_count': 61,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855874936295927809,
#    u'id_str': u'855874936295927809',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'quoted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Apr 22 19:25:21 +0000 2017',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 83470331,
#        u'id_str': u'83470331',
#        u'indices': [0, 11],
#        u'name': u'Amused Chimp \U0001f1fa\U0001f1f8',
#        u'screen_name': u'AmuseChimp'}]},
#     u'favorite_count': 183,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 855865123973382144,
#     u'id_str': u'855865123973382144',
#     u'in_reply_to_screen_name': u'AmuseChimp',
#     u'in_reply_to_status_id': 855842343915626496,
#     u'in_reply_to_status_id_str': u'855842343915626496',
#     u'in_reply_to_user_id': 83470331,
#     u'in_reply_to_user_id_str': u'83470331',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 47,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     u'text': u'@AmuseChimp I mute the nitpickers, block the outraged, like the kind, follow the insightful.',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'Present',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#          u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/VPBBapmlY4'}]}},
#      u'favourites_count': 34041,
#      u'follow_request_sent': False,
#      u'followers_count': 210441,
#      u'following': True,
#      u'friends_count': 426,
#      u'geo_enabled': True,
#      u'has_extended_profile': False,
#      u'id': 745273,
#      u'id_str': u'745273',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 4794,
#      u'location': u'San Francisco, CA',
#      u'name': u'Naval Ravikant',
#      u'notifications': False,
#      u'profile_background_color': u'352726',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#      u'profile_link_color': u'D02B55',
#      u'profile_sidebar_border_color': u'829D5E',
#      u'profile_sidebar_fill_color': u'99CC33',
#      u'profile_text_color': u'3E4415',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'naval',
#      u'statuses_count': 14081,
#      u'time_zone': u'Pacific Time (US & Canada)',
#      u'translator_type': u'none',
#      u'url': u'https://t.co/VPBBapmlY4',
#      u'utc_offset': -25200,
#      u'verified': False}},
#    u'quoted_status_id': 855865123973382144,
#    u'quoted_status_id_str': u'855865123973382144',
#    u'retweet_count': 20,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    u'text': u'Good twitter advice, even better life advice from @naval https://t.co/uQZMUAVddI',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri May 08 21:02:27 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Investor. Board Member. Fund Advisor. Former CEO. Cancer survivor. Managing Partner, Treehouse Capital LLC.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'treehousecapital.com',
#         u'expanded_url': u'http://www.treehousecapital.com',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/dUUniJna21'}]}},
#     u'favourites_count': 16,
#     u'follow_request_sent': False,
#     u'followers_count': 4340,
#     u'following': False,
#     u'friends_count': 500,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 38743751,
#     u'id_str': u'38743751',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 287,
#     u'location': u'Oakland, California',
#     u'name': u'Rob Majteles',
#     u'notifications': False,
#     u'profile_background_color': u'BAD8DE',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/665455254/5ef839d8fbd7e5e4eab4853ee8c82854.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/665455254/5ef839d8fbd7e5e4eab4853ee8c82854.jpeg',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/38743751/1398282458',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/794631728920788992/LM95LuXX_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/794631728920788992/LM95LuXX_normal.jpg',
#     u'profile_link_color': u'05090F',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'D9E0F2',
#     u'profile_text_color': u'04141A',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'treehcapital',
#     u'statuses_count': 41466,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/dUUniJna21',
#     u'utc_offset': -25200,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   u'text': u'RT @treehcapital: Good twitter advice, even better life advice from @naval https://t.co/uQZMUAVddI',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 34041,
#    u'follow_request_sent': False,
#    u'followers_count': 210441,
#    u'following': True,
#    u'friends_count': 426,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4794,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14081,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 19:56:30 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 1236101,
#      u'id_str': u'1236101',
#      u'indices': [3, 17],
#      u'name': u'Benedict Evans',
#      u'screen_name': u'BenedictEvans'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855872962804633600,
#   u'id_str': u'855872962804633600',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 74,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Fri Jun 03 18:59:26 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 240,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 738807320214265856,
#    u'id_str': u'738807320214265856',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 74,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'If you have to rephrase what someone said, using none of their words, to explain why it makes you angry, you should probably read it again',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Mar 15 17:33:00 +0000 2007',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"Trying to work out what's going on, and what happens next. Curious. Easily bored. Single parent. Expat in San Francisco. @a16z",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'ben-evans.com',
#         u'expanded_url': u'http://www.ben-evans.com/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/CBKvGBbodE'}]}},
#     u'favourites_count': 8758,
#     u'follow_request_sent': False,
#     u'followers_count': 213625,
#     u'following': False,
#     u'friends_count': 985,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 1236101,
#     u'id_str': u'1236101',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 5970,
#     u'location': u'',
#     u'name': u'Benedict Evans',
#     u'notifications': False,
#     u'profile_background_color': u'E5E5E5',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/3670821/mandolux-three-r-1440.jpg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/3670821/mandolux-three-r-1440.jpg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1236101/1491213038',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/845396356579508224/1ruiOPLI_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/845396356579508224/1ruiOPLI_normal.jpg',
#     u'profile_link_color': u'336699',
#     u'profile_sidebar_border_color': u'5D5D5D',
#     u'profile_sidebar_fill_color': u'E5E5E5',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'BenedictEvans',
#     u'statuses_count': 110313,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/CBKvGBbodE',
#     u'utc_offset': -25200,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   u'text': u'RT @BenedictEvans: If you have to rephrase what someone said, using none of their words, to explain why it makes you angry, you should prob\u2026',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 34041,
#    u'follow_request_sent': False,
#    u'followers_count': 210441,
#    u'following': True,
#    u'friends_count': 426,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4794,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14081,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 19:51:48 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'youtube.com/watch?v=ptH_gd\u2026',
#      u'expanded_url': u'https://www.youtube.com/watch?v=ptH_gd_xmPQ&feature=share',
#      u'indices': [40, 63],
#      u'url': u'https://t.co/PJMZIGKG8s'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855871781927780352,
#   u'id_str': u'855871781927780352',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'Blue Ocean Strategy - Steps to innovate https://t.co/PJMZIGKG8s',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Nov 14 12:38:24 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'CEO @Highrise spin-off of @Basecamp. @YCombinator alum. Created Draft (https://t.co/Jo90LmNDMm). Writer: https://t.co/oBsSgOZNc1 & vlogger',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'draftin.com',
#        u'expanded_url': u'http://draftin.com',
#        u'indices': [71, 94],
#        u'url': u'https://t.co/Jo90LmNDMm'},
#       {u'display_url': u'medium.com/@natekontny',
#        u'expanded_url': u'http://medium.com/@natekontny',
#        u'indices': [105, 128],
#        u'url': u'https://t.co/oBsSgOZNc1'}]},
#     u'url': {u'urls': [{u'display_url': u'youtube.com/NathanKontny',
#        u'expanded_url': u'http://youtube.com/NathanKontny',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/5C3KjyyAjl'}]}},
#    u'favourites_count': 13575,
#    u'follow_request_sent': False,
#    u'followers_count': 12076,
#    u'following': True,
#    u'friends_count': 571,
#    u'geo_enabled': False,
#    u'has_extended_profile': True,
#    u'id': 17386551,
#    u'id_str': u'17386551',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 540,
#    u'location': u'Chicago',
#    u'name': u'Nathan Kontny',
#    u'notifications': False,
#    u'profile_background_color': u'1A1B1F',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/17386551/1483225957',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1769389798/image1327095694_normal.png',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1769389798/image1327095694_normal.png',
#    u'profile_link_color': u'7696BF',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'252429',
#    u'profile_text_color': u'666666',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'natekontny',
#    u'statuses_count': 10053,
#    u'time_zone': u'Central Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/5C3KjyyAjl',
#    u'utc_offset': -18000,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 19:40:00 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 15335709,
#      u'id_str': u'15335709',
#      u'indices': [3, 11],
#      u'name': u'Sizhao Yang',
#      u'screen_name': u'zaoyang'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855868812750495744,
#   u'id_str': u'855868812750495744',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'quoted_status_id': 855477378469974016,
#   u'quoted_status_id_str': u'855477378469974016',
#   u'retweet_count': 2,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 15:48:53 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/8\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/855810649640902660',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/G6TrCVMPvf'}],
#     u'user_mentions': []},
#    u'favorite_count': 38,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855810649640902660,
#    u'id_str': u'855810649640902660',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'quoted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Apr 21 17:44:35 +0000 2017',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'favorite_count': 708,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 855477378469974016,
#     u'id_str': u'855477378469974016',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 204,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     u'text': u'VCs, universities, and accelerators provide more value from filtering and credentialing than they do from educating and advising.',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'Present',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#          u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/VPBBapmlY4'}]}},
#      u'favourites_count': 34041,
#      u'follow_request_sent': False,
#      u'followers_count': 210441,
#      u'following': True,
#      u'friends_count': 426,
#      u'geo_enabled': True,
#      u'has_extended_profile': False,
#      u'id': 745273,
#      u'id_str': u'745273',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 4794,
#      u'location': u'San Francisco, CA',
#      u'name': u'Naval Ravikant',
#      u'notifications': False,
#      u'profile_background_color': u'352726',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#      u'profile_link_color': u'D02B55',
#      u'profile_sidebar_border_color': u'829D5E',
#      u'profile_sidebar_fill_color': u'99CC33',
#      u'profile_text_color': u'3E4415',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'naval',
#      u'statuses_count': 14081,
#      u'time_zone': u'Pacific Time (US & Canada)',
#      u'translator_type': u'none',
#      u'url': u'https://t.co/VPBBapmlY4',
#      u'utc_offset': -25200,
#      u'verified': False}},
#    u'quoted_status_id': 855477378469974016,
#    u'quoted_status_id_str': u'855477378469974016',
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'Most VCs get their value from deal flow and picking. Kingmaker vs picking the king is only a debate for people that\u2026 https://t.co/G6TrCVMPvf',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Jul 06 21:10:02 +0000 2008',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Angel investor in Wish. Co-creator of @farmville. Always interested in good links and books.',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 4941,
#     u'follow_request_sent': False,
#     u'followers_count': 4004,
#     u'following': False,
#     u'friends_count': 5000,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 15335709,
#     u'id_str': u'15335709',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 226,
#     u'location': u'San Francisco',
#     u'name': u'Sizhao Yang',
#     u'notifications': False,
#     u'profile_background_color': u'B2DFDA',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1507449402/download_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1507449402/download_normal.jpg',
#     u'profile_link_color': u'93A644',
#     u'profile_sidebar_border_color': u'EEEEEE',
#     u'profile_sidebar_fill_color': u'FFFFFF',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'zaoyang',
#     u'statuses_count': 8488,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': -25200,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   u'text': u"RT @zaoyang: Most VCs get their value from deal flow and picking. Kingmaker vs picking the king is only a debate for people that haven't do\u2026",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 34041,
#    u'follow_request_sent': False,
#    u'followers_count': 210441,
#    u'following': True,
#    u'friends_count': 426,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4794,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14081,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 19:39:15 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/I7QUvC3FMw',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855868622803042304/photo/1',
#      u'id': 855868062821629952,
#      u'id_str': u'855868062821629952',
#      u'indices': [116, 139],
#      u'media_url': u'http://pbs.twimg.com/media/C-Cnd_MVwAAWK-V.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C-Cnd_MVwAAWK-V.jpg',
#      u'sizes': {u'large': {u'h': 444, u'resize': u'fit', u'w': 738},
#       u'medium': {u'h': 444, u'resize': u'fit', u'w': 738},
#       u'small': {u'h': 409, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/I7QUvC3FMw'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2pMpbIw',
#      u'expanded_url': u'http://tcrn.ch/2pMpbIw',
#      u'indices': [92, 115],
#      u'url': u'https://t.co/fYs5SA5P7o'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/I7QUvC3FMw',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855868622803042304/photo/1',
#      u'id': 855868062821629952,
#      u'id_str': u'855868062821629952',
#      u'indices': [116, 139],
#      u'media_url': u'http://pbs.twimg.com/media/C-Cnd_MVwAAWK-V.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C-Cnd_MVwAAWK-V.jpg',
#      u'sizes': {u'large': {u'h': 444, u'resize': u'fit', u'w': 738},
#       u'medium': {u'h': 444, u'resize': u'fit', u'w': 738},
#       u'small': {u'h': 409, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/I7QUvC3FMw'}]},
#   u'favorite_count': 16,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855868622803042304,
#   u'id_str': u'855868622803042304',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 17,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'Weekly Roundup: Facebook\u2019s F8, Confide hit with lawsuit, Juicero defends its tech, and more https://t.co/fYs5SA5P7o https://t.co/I7QUvC3FMw',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1925,
#    u'follow_request_sent': False,
#    u'followers_count': 8949230,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108984,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154543,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 19:23:42 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 83470331,
#      u'id_str': u'83470331',
#      u'indices': [3, 14],
#      u'name': u'Amused Chimp \U0001f1fa\U0001f1f8',
#      u'screen_name': u'AmuseChimp'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855864708691181568,
#   u'id_str': u'855864708691181568',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 11,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 17:54:50 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 59,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855842343915626496,
#    u'id_str': u'855842343915626496',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'retweet_count': 11,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'most try to correct your tweets, few actually give any value back',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Oct 18 23:14:58 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 14391,
#     u'follow_request_sent': False,
#     u'followers_count': 6337,
#     u'following': False,
#     u'friends_count': 85,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 83470331,
#     u'id_str': u'83470331',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 129,
#     u'location': u'A Tree',
#     u'name': u'Amused Chimp \U0001f1fa\U0001f1f8',
#     u'notifications': False,
#     u'profile_background_color': u'ABB8C2',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/479324103619276800/_u6OeKJ4.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/479324103619276800/_u6OeKJ4.jpeg',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/83470331/1477617188',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/809560462828433408/JiGFyAE4_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/809560462828433408/JiGFyAE4_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'C0DFEC',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'AmuseChimp',
#     u'statuses_count': 508,
#     u'time_zone': u'Central Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   u'text': u'RT @AmuseChimp: most try to correct your tweets, few actually give any value back',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 34041,
#    u'follow_request_sent': False,
#    u'followers_count': 210441,
#    u'following': True,
#    u'friends_count': 426,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4794,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14081,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}}]

# %%
# import request
# import time

type(home_timeline)
# Out:
# str

# %%
type(content)
# Out:
# list

# %% [markdown]
# install this http://mike.verdone.ca/twitter/#install

# %%
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream
# del twitter
import time
import json

# %%
# def rate_lim():
oauth = OAuth(token_key, token_secret, consumer_key, consumer_secret)
twitter = Twitter(auth=oauth)
iterator = twitter.search.tweets(q='#bostonmarathon', result_type='recent', lang='en', count=2)
#     with open("out.txt", "w"):
#         fo.write(json.dumps(iterator))
print(iterator)
# Out:
# {u'search_metadata': {u'count': 2, u'completed_in': 0.044, u'max_id_str': u'856311837792632832', u'since_id_str': u'0', u'next_results': u'?max_id=856310995404427263&q=%23bostonmarathon&lang=en&count=2&include_entities=1&result_type=recent', u'refresh_url': u'?since_id=856311837792632832&q=%23bostonmarathon&lang=en&result_type=recent&include_entities=1', u'since_id': 0, u'query': u'%23bostonmarathon', u'max_id': 856311837792632832}, u'statuses': [{u'contributors': None, u'truncated': False, u'text': u'RT @korf13: @therunchat helped a guy finish the #BostonMarathon. It was pretty awesome. Found out he had a body temp of 108\xb0. He is fine no\u2026', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 856311837792632832, u'favorite_count': 0, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 479976419, u'indices': [3, 10], u'id_str': u'479976419', u'screen_name': u'korf13', u'name': u'mike korfhage'}, {u'id': 474027370, u'indices': [12, 23], u'id_str': u'474027370', u'screen_name': u'therunchat', u'name': u'#RunChat'}], u'hashtags': [{u'indices': [48, 63], u'text': u'BostonMarathon'}], u'urls': []}, u'retweeted': False, u'coordinates': None, u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 1, u'id_str': u'856311837792632832', u'favorited': False, u'retweeted_status': {u'contributors': None, u'truncated': True, u'text': u'@therunchat helped a guy finish the #BostonMarathon. It was pretty awesome. Found out he had a body temp of 108\xb0. H\u2026 https://t.co/49m1A6pkUg', u'is_quote_status': False, u'in_reply_to_status_id': 856309967510319108, u'id': 856310995404427264, u'favorite_count': 9, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 474027370, u'indices': [0, 11], u'id_str': u'474027370', u'screen_name': u'therunchat', u'name': u'#RunChat'}], u'hashtags': [{u'indices': [36, 51], u'text': u'BostonMarathon'}], u'urls': [{u'url': u'https://t.co/49m1A6pkUg', u'indices': [117, 140], u'expanded_url': u'https://twitter.com/i/web/status/856310995404427264', u'display_url': u'twitter.com/i/web/status/8\u2026'}]}, u'retweeted': False, u'coordinates': None, u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', u'in_reply_to_screen_name': u'therunchat', u'in_reply_to_user_id': 474027370, u'retweet_count': 1, u'id_str': u'856310995404427264', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 479976419, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/785645287129903105/cxh0wSCF_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 768, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'479976419', u'profile_background_color': u'C0DEED', u'listed_count': 50, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 10593, u'description': u'4xBoston Finisher. Ironman Finisher. Grow older. Train harder. Run faster. #BBN. Sub 3 marathoner. Louisville,Ky. #bqchat', u'friends_count': 275, u'location': u'', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://pbs.twimg.com/profile_images/785645287129903105/cxh0wSCF_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/479976419/1492836631', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'korf13', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 6909, u'name': u'mike korfhage', u'notifications': False, u'url': None, u'created_at': u'Wed Feb 0 ...

# %%
twitter_stream = TwitterStream(auth=oauth)
iterator = twitter_stream.statuses.filter(track="#bostonmarathon,#bostonmarathon2017,",language="en")
tweet_count = 5
for tweet in iterator:
    tweet_count -= 1
    # Twitter Python Tool wraps the data returned by Twitter 
    # as a TwitterDictResponse object.
    # We convert it back to the JSON format to print/score
    print(tweet_count)
    print("\n\n\n")
    print(json.dumps(tweet))
    # The command below will do pretty printing for JSON data, try it out
    # print json.dumps(tweet, indent=4) 
    if tweet_count <= 0:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-512d8e3e284c> in <module>()
#       3 iterator = twitter_stream.statuses.filter(track="#bostonmarathon,#bostonmarathon2017,",language="en")
#       4 tweet_count = 5
# ----> 5 for tweet in iterator:
#       6     tweet_count -= 1
#       7     # Twitter Python Tool wraps the data returned by Twitter
#
# /Users/km/anaconda/lib/python2.7/site-packages/twitter-1.17.1-py2.7.egg/twitter/stream.pyc in __iter__(self)
#     174         while True:
#     175             # Decode all the things:
# --> 176             data = sock_reader.read()
#     177             dechunked_data, end_of_stream, decode_error = chunk_decoder.decode(data)
#     178             unicode_data = utf8_decoder.decode(dechunked_data)
#
# /Users/km/anaconda/lib/python2.7/site-packages/twitter-1.17.1-py2.7.egg/twitter/stream.pyc in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# KeyboardInterrupt:

# %%
def streamer():
    
    
    
    twitter_stream = TwitterStream(auth=oauth)
    
    iterator = twitter_stream.statuses.filter(track="#bostonmarathon,#bostonmarathon2017,",language="en")

    fo = open("my.txt", "ab")
  
    tweet_count = 5
    
    for tweet in iterator:
        tweet_count -= 1
        # Twitter Python Tool wraps the data returned by Twitter 
        # as a TwitterDictResponse object.
        # We convert it back to the JSON format to print/score
        fo.write(json.dumps(tweet)) 
        fo.write(",")
        print tweet_count
        # The command below will do pretty printing for JSON data, try it out
        # print json.dumps(tweet, indent=4) 
        if tweet_count <= 0:
            break     
        
    # Close opend file
    fo.close()

# %%
streamer()
# Out:
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-ad971273336a> in <module>()
# ----> 1 streamer()
#
# <ipython-input-31-da5f008230a8> in streamer()
#      13     tweet_count = 5
#      14
# ---> 15     for tweet in iterator:
#      16         tweet_count -= 1
#      17         # Twitter Python Tool wraps the data returned by Twitter
#
# /Users/km/anaconda/lib/python2.7/site-packages/twitter-1.17.1-py2.7.egg/twitter/stream.pyc in __iter__(self)
#     174         while True:
#     175             # Decode all the things:
# --> 176             data = sock_reader.read()
#     177             dechunked_data, end_of_stream, decode_error = chunk_decoder.decode(data)
#     178             unicode_data = utf8_decoder.decode(dechunked_data)
#
# /Users/km/anaconda/lib/python2.7/site-packages/twitter-1.17.1-py2.7.egg/twitter/stream.pyc in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# KeyboardInterrupt:

# %%
# just run all these cells,

# %%
print """
# first thing you need to do is get access tokens from twitter, 
# go to https://apps.twitter.com, create an app, create API access token,
# then fill out tokens.txt file in directory where .ipynb is sitting
# dont add tokens.txt file to git. leave it untracked. 
# (smart people in the internet say NEVER SHARE KEYS, never commit them to github and stuff)"""

with open('tokens.txt','w') as fout:
    fout.write('Consumer key\n')
    fout.write('Consumer secret\n')
    fout.write('token key\n')
    fout.write('token secret\n')
# Out:
# # first thing you need to do is get access tokens from twitter,
# # go to https://apps.twitter.com, create an app, create API access token,
# # then fill out tokens.txt file in directory where .ipynb is sitting
# # dont add tokens.txt file to git. leave it untracked.
# # (smart people in the internet say NEVER SHARE KEYS, never commit them to github and stuff)

# %%
import os

try: # i out my tokens into ENV variables, cuz that seems to be the practice,
     # if use stuff like that -- use it, if no, just use the tokens.txt file, ignore this code 
    consumer_key = os.environ['TWITTER_CONSUMER_KEY']
    consumer_secret = os.environ['TWITTER_CONSUMER_SECRET']
    token_key = os.environ['TWITTER_TOKENCS506_KEY']
    token_secret = os.environ['TWITTER_TOKENCS506_SECRET']
    
except:
    with open('tokens.txt','r') as fin:
        consumer_key = fin.readline()[:-1]
        consumer_secret = fin.readline().rstrip()
        token_key = fin.readline()[:-1]
        token_secret = fin.readline().rstrip()

# %% [markdown]
# ---

# %%
# our first attept from GSU, get your home page 
# if you repeat this cell several times, it's easy to get banned
import oauth2
import json

def oauth_req(url, key, secret, http_method="GET", post_body="", http_headers=None):
    consumer = oauth2.Consumer(key=consumer_key, secret=consumer_secret)
    token = oauth2.Token(key=key, secret=secret)
    client = oauth2.Client(consumer, token)
    resp, content = client.request( url, method=http_method, body=post_body, headers=http_headers )
    return content

home_timeline = oauth_req( 'https://api.twitter.com/1.1/statuses/home_timeline.json', token_key, token_secret)

content = json.loads(home_timeline)
content[:10]

# for key in content[0]:
#     print key, content[key]
    
# print content[0].items()


# output = json.dumps(home_timeline)
# print output
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 01:00:24 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2pNk4rm',
#      u'expanded_url': u'http://tcrn.ch/2pNk4rm',
#      u'indices': [56, 79],
#      u'url': u'https://t.co/vCSZv5ISKv'}],
#    u'user_mentions': [{u'id': 109968678,
#      u'id_str': u'109968678',
#      u'indices': [83, 94],
#      u'name': u'Katie Roof',
#      u'screen_name': u'Katie_Roof'}]},
#   u'favorite_count': 19,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855587054058602496,
#   u'id_str': u'855587054058602496',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 8,
#   u'retweeted': False,
#   u'source': u'<a href="http://10up.com" rel="nofollow">10up Publish Tweet</a>',
#   u'text': u'HBO\'s "Silicon Valley" cast hints about upcoming season https://t.co/vCSZv5ISKv by @Katie_Roof',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1926,
#    u'follow_request_sent': False,
#    u'followers_count': 8942326,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108945,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154506,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:56:04 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/i/web/status/8\u2026',
#      u'expanded_url': u'https://twitter.com/i/web/status/855585963187159040',
#      u'indices': [117, 140],
#      u'url': u'https://t.co/n4Y3cOWoat'}],
#    u'user_mentions': []},
#   u'favorite_count': 17,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855585963187159040,
#   u'id_str': u'855585963187159040',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'quoted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Apr 02 07:29:06 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'forum.z.cash/t/there-are-th\u2026',
#       u'expanded_url': u'https://forum.z.cash/t/there-are-three-different-flavors-of-project-alchemy/13963/6',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/xLtGbiKf8L'}],
#     u'user_mentions': []},
#    u'favorite_count': 67,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 848437116853825536,
#    u'id_str': u'848437116853825536',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 29,
#    u'retweeted': False,
#    u'source': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#    u'text': u"\u201cLet's face the harsh truth: a very plausible future outcome is that all cryptocurrencies dwindle into irrelevance.\u201d\u2014https://t.co/xLtGbiKf8L",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Mar 20 04:21:11 +0000 2008',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"https://t.co/ZhS7ISijC1 / https://t.co/uFbVKbezYa / I sometimes tweet links to things I disagree with or disbelieve, but never things I haven't read.",
#     u'entities': {u'description': {u'urls': [{u'display_url': u'z.cash',
#         u'expanded_url': u'https://z.cash',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/ZhS7ISijC1'},
#        {u'display_url': u'ketotic.org',
#         u'expanded_url': u'http://ketotic.org',
#         u'indices': [26, 49],
#         u'url': u'https://t.co/uFbVKbezYa'}]},
#      u'url': {u'urls': [{u'display_url': u'z.cash',
#         u'expanded_url': u'https://z.cash/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/DChvLxqLAf'}]}},
#     u'favourites_count': 65750,
#     u'follow_request_sent': False,
#     u'followers_count': 12265,
#     u'following': False,
#     u'friends_count': 853,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 14182218,
#     u'id_str': u'14182218',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 619,
#     u'location': u'Boulder, Colorado, USA, Earth',
#     u'name': u'zooko',
#     u'notifications': False,
#     u'profile_background_color': u'9AE4E8',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/839044582390317056/cPPnpIeA.jpg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/839044582390317056/cPPnpIeA.jpg',
#     u'profile_background_tile': True,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/815539688001912832/g2yx0uMf_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/815539688001912832/g2yx0uMf_normal.jpg',
#     u'profile_link_color': u'91D2FA',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'E0FF92',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'zooko',
#     u'statuses_count': 44936,
#     u'time_zone': u'Monrovia',
#     u'translator_type': u'regular',
#     u'url': u'https://t.co/DChvLxqLAf',
#     u'utc_offset': 0,
#     u'verified': False}},
#   u'quoted_status_id': 848437116853825536,
#   u'quoted_status_id_str': u'848437116853825536',
#   u'retweet_count': 4,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'"...focus on creating value for mainstream users instead of focusing on competing with other tiny, fragile, low-val\u2026 https://t.co/n4Y3cOWoat',
#   u'truncated': True,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 33851,
#    u'follow_request_sent': False,
#    u'followers_count': 210366,
#    u'following': True,
#    u'friends_count': 424,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4798,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14047,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:54:44 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/icalltopsolo/s\u2026',
#      u'expanded_url': u'https://twitter.com/icalltopsolo/status/855558318797930496',
#      u'indices': [56, 79],
#      u'url': u'https://t.co/0LFYJMJwck'},
#     {u'display_url': u'twitter.com/normonics/stat\u2026',
#      u'expanded_url': u'https://twitter.com/normonics/status/855582923747082241',
#      u'indices': [85, 108],
#      u'url': u'https://t.co/RqSIOwEsF0'}],
#    u'user_mentions': [{u'id': 381813372,
#      u'id_str': u'381813372',
#      u'indices': [3, 13],
#      u'name': u'Joe Norman',
#      u'screen_name': u'normonics'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855585630562074624,
#   u'id_str': u'855585630562074624',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'quoted_status_id': 855582923747082241,
#   u'quoted_status_id_str': u'855582923747082241',
#   u'retweet_count': 4,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 00:44:08 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/icalltopsolo/s\u2026',
#       u'expanded_url': u'https://twitter.com/icalltopsolo/status/855558318797930496',
#       u'indices': [41, 64],
#       u'url': u'https://t.co/0LFYJMJwck'},
#      {u'display_url': u'twitter.com/normonics/stat\u2026',
#       u'expanded_url': u'https://twitter.com/normonics/status/855582923747082241',
#       u'indices': [70, 93],
#       u'url': u'https://t.co/RqSIOwEsF0'}],
#     u'user_mentions': []},
#    u'favorite_count': 2,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855582962783367168,
#    u'id_str': u'855582962783367168',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'quoted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Apr 22 00:43:59 +0000 2017',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/normonics/stat\u2026',
#        u'expanded_url': u'https://twitter.com/normonics/status/855582878398242816',
#        u'indices': [61, 84],
#        u'url': u'https://t.co/bQe1z6JKJc'}],
#      u'user_mentions': []},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 855582923747082241,
#     u'id_str': u'855582923747082241',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': True,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'possibly_sensitive_appealable': False,
#     u'quoted_status_id': 855582878398242816,
#     u'quoted_status_id_str': u'855582878398242816',
#     u'retweet_count': 1,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"I'm neither supportive nor opposed the 'concept' of GMO 2/25 https://t.co/bQe1z6JKJc",
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Thu Sep 29 00:13:37 +0000 2011',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'Complex Systems and Data Scientist. New England Complex Systems Institute affiliate. views mine.',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'jwnorman.com',
#          u'expanded_url': u'http://www.jwnorman.com',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/5uMZgZgyVP'}]}},
#      u'favourites_count': 4301,
#      u'follow_request_sent': False,
#      u'followers_count': 1440,
#      u'following': False,
#      u'friends_count': 814,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 381813372,
#      u'id_str': u'381813372',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 54,
#      u'location': u'',
#      u'name': u'Joe Norman',
#      u'notifications': False,
#      u'profile_background_color': u'ABB8C2',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/381813372/1455575921',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/811037307784478720/z2A6q8Sq_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/811037307784478720/z2A6q8Sq_normal.jpg',
#      u'profile_link_color': u'3B94D9',
#      u'profile_sidebar_border_color': u'000000',
#      u'profile_sidebar_fill_color': u'000000',
#      u'profile_text_color': u'000000',
#      u'profile_use_background_image': False,
#      u'protected': False,
#      u'screen_name': u'normonics',
#      u'statuses_count': 6681,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': u'https://t.co/5uMZgZgyVP',
#      u'utc_offset': None,
#      u'verified': False}},
#    u'quoted_status_id': 855582923747082241,
#    u'quoted_status_id_str': u'855582923747082241',
#    u'retweet_count': 4,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Start here and click through - reply to: https://t.co/0LFYJMJwck 1/25 https://t.co/RqSIOwEsF0',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Sep 29 00:13:37 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Complex Systems and Data Scientist. New England Complex Systems Institute affiliate. views mine.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'jwnorman.com',
#         u'expanded_url': u'http://www.jwnorman.com',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/5uMZgZgyVP'}]}},
#     u'favourites_count': 4301,
#     u'follow_request_sent': False,
#     u'followers_count': 1440,
#     u'following': False,
#     u'friends_count': 814,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 381813372,
#     u'id_str': u'381813372',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 54,
#     u'location': u'',
#     u'name': u'Joe Norman',
#     u'notifications': False,
#     u'profile_background_color': u'ABB8C2',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/381813372/1455575921',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/811037307784478720/z2A6q8Sq_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/811037307784478720/z2A6q8Sq_normal.jpg',
#     u'profile_link_color': u'3B94D9',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'normonics',
#     u'statuses_count': 6681,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'https://t.co/5uMZgZgyVP',
#     u'utc_offset': None,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @normonics: Start here and click through - reply to: https://t.co/0LFYJMJwck 1/25 https://t.co/RqSIOwEsF0',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 33851,
#    u'follow_request_sent': False,
#    u'followers_count': 210366,
#    u'following': True,
#    u'friends_count': 424,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4798,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14047,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:54:20 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'xudongz.com/blog/2017/idn-\u2026',
#      u'expanded_url': u'https://www.xudongz.com/blog/2017/idn-phishing/',
#      u'indices': [50, 73],
#      u'url': u'https://t.co/bn9dMG0L1t'}],
#    u'user_mentions': [{u'id': 341244014,
#      u'id_str': u'341244014',
#      u'indices': [3, 16],
#      u'name': u'Xudong Zheng',
#      u'screen_name': u'Xudong_Zheng'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855585525868244993,
#   u'id_str': u'855585525868244993',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 136,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Fri Apr 14 13:16:10 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'xudongz.com/blog/2017/idn-\u2026',
#       u'expanded_url': u'https://www.xudongz.com/blog/2017/idn-phishing/',
#       u'indices': [32, 55],
#       u'url': u'https://t.co/bn9dMG0L1t'}],
#     u'user_mentions': []},
#    u'favorite_count': 135,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 852873111926132736,
#    u'id_str': u'852873111926132736',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 136,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Phishing with Unicode Domains - https://t.co/bn9dMG0L1t',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Jul 24 01:55:59 +0000 2011',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'I am Xudong and I create websites.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'xudongz.com',
#         u'expanded_url': u'https://www.xudongz.com/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/bZPFQH0yCv'}]}},
#     u'favourites_count': 67,
#     u'follow_request_sent': False,
#     u'followers_count': 470,
#     u'following': False,
#     u'friends_count': 819,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 341244014,
#     u'id_str': u'341244014',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 3,
#     u'location': u'',
#     u'name': u'Xudong Zheng',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/649804826453250048/WBuqGj8a_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/649804826453250048/WBuqGj8a_normal.png',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Xudong_Zheng',
#     u'statuses_count': 48,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'translator_type': u'regular',
#     u'url': u'https://t.co/bZPFQH0yCv',
#     u'utc_offset': -14400,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'RT @Xudong_Zheng: Phishing with Unicode Domains - https://t.co/bn9dMG0L1t',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Jun 03 13:23:08 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Journalist, eSports commentator, cyberathlete and physicist',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'about.me/duanyt',
#        u'expanded_url': u'http://about.me/duanyt',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/BRjCmCpDUo'}]}},
#    u'favourites_count': 825,
#    u'follow_request_sent': False,
#    u'followers_count': 255,
#    u'following': True,
#    u'friends_count': 178,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 6541242,
#    u'id_str': u'6541242',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 12,
#    u'location': u'Boston, MA',
#    u'name': u'Duan Yutong',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/6541242/1354854390',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/477744471086751744/n2Bp0b5A_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/477744471086751744/n2Bp0b5A_normal.jpeg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'givoltage',
#    u'statuses_count': 6374,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'translator_type': u'regular',
#    u'url': u'https://t.co/BRjCmCpDUo',
#    u'utc_offset': -14400,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:52:57 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'\u0430\u0440\u0440\u04cf\u0435.com',
#      u'expanded_url': u'https://xn--80ak6aa92e.com',
#      u'indices': [59, 82],
#      u'url': u'https://t.co/Eawy6gdty4'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855585178407895041,
#   u'id_str': u'855585178407895041',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': {u'attributes': {},
#    u'bounding_box': {u'coordinates': [[[-71.191421, 42.227797],
#       [-70.986004, 42.227797],
#       [-70.986004, 42.399542],
#       [-71.191421, 42.399542]]],
#     u'type': u'Polygon'},
#    u'contained_within': [],
#    u'country': u'United States',
#    u'country_code': u'US',
#    u'full_name': u'Boston, MA',
#    u'id': u'67b98f17fdcf20be',
#    u'name': u'Boston',
#    u'place_type': u'city',
#    u'url': u'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json'},
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u"Here's a link to Apple's homepage. Will it take you there? https://t.co/Eawy6gdty4",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Jun 03 13:23:08 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Journalist, eSports commentator, cyberathlete and physicist',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'about.me/duanyt',
#        u'expanded_url': u'http://about.me/duanyt',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/BRjCmCpDUo'}]}},
#    u'favourites_count': 825,
#    u'follow_request_sent': False,
#    u'followers_count': 255,
#    u'following': True,
#    u'friends_count': 178,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 6541242,
#    u'id_str': u'6541242',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 12,
#    u'location': u'Boston, MA',
#    u'name': u'Duan Yutong',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/6541242/1354854390',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/477744471086751744/n2Bp0b5A_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/477744471086751744/n2Bp0b5A_normal.jpeg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'givoltage',
#    u'statuses_count': 6374,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'translator_type': u'regular',
#    u'url': u'https://t.co/BRjCmCpDUo',
#    u'utc_offset': -14400,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:52:04 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/XNsoUlDbAI',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855584956743122944/photo/1',
#      u'id': 855584954654355456,
#      u'id_str': u'855584954654355456',
#      u'indices': [75, 98],
#      u'media_url': u'http://pbs.twimg.com/media/C9-l-7FXcAAyabK.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C9-l-7FXcAAyabK.jpg',
#      u'sizes': {u'large': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'medium': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'small': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/XNsoUlDbAI'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2pN6I1v',
#      u'expanded_url': u'http://tcrn.ch/2pN6I1v',
#      u'indices': [51, 74],
#      u'url': u'https://t.co/9kqZ1Md8SY'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/XNsoUlDbAI',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855584956743122944/photo/1',
#      u'id': 855584954654355456,
#      u'id_str': u'855584954654355456',
#      u'indices': [75, 98],
#      u'media_url': u'http://pbs.twimg.com/media/C9-l-7FXcAAyabK.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C9-l-7FXcAAyabK.jpg',
#      u'sizes': {u'large': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'medium': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'small': {u'h': 373, u'resize': u'fit', u'w': 675},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/XNsoUlDbAI'}]},
#   u'favorite_count': 8,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855584956743122944,
#   u'id_str': u'855584956743122944',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 7,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   u'text': u'A Midas List VC on the problem with the Midas List https://t.co/9kqZ1Md8SY https://t.co/XNsoUlDbAI',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1926,
#    u'follow_request_sent': False,
#    u'followers_count': 8942326,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108945,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154506,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:39:59 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/kmac/status/82\u2026',
#      u'expanded_url': u'https://twitter.com/kmac/status/828177722111168512',
#      u'indices': [51, 74],
#      u'url': u'https://t.co/GMEeH9fpLt'}],
#    u'user_mentions': []},
#   u'favorite_count': 22,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855581916317179905,
#   u'id_str': u'855581916317179905',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'quoted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Feb 05 09:45:30 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'theconversation.com/maybe-moderate\u2026',
#       u'expanded_url': u'http://theconversation.com/maybe-moderate-drinking-isnt-so-good-for-you-after-all-72266',
#       u'indices': [89, 112],
#       u'url': u'https://t.co/9k9KIX46Z7'}],
#     u'user_mentions': []},
#    u'favorite_count': 387,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 828177722111168512,
#    u'id_str': u'828177722111168512',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 419,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"So, all those studies claiming moderate drinking is beneficial DIDN'T CONTROL FOR WEALTH https://t.co/9k9KIX46Z7",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Mar 23 17:24:01 +0000 2007',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Was at @FT & @FTalpha, now at @climateinstitut. Background pic by William Yang; platypus bird bath by my dad.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'tinyletter.com/kmackenzie',
#         u'expanded_url': u'https://tinyletter.com/kmackenzie',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/PaVJM2FVON'}]}},
#     u'favourites_count': 9845,
#     u'follow_request_sent': False,
#     u'followers_count': 6415,
#     u'following': False,
#     u'friends_count': 2584,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 2032411,
#     u'id_str': u'2032411',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 397,
#     u'location': u'Sydney',
#     u'name': u'Kate Mackenzie',
#     u'notifications': False,
#     u'profile_background_color': u'709397',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2032411/1414139020',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/811560743329873920/Jm_02F2a_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/811560743329873920/Jm_02F2a_normal.jpg',
#     u'profile_link_color': u'FF3300',
#     u'profile_sidebar_border_color': u'86A4A6',
#     u'profile_sidebar_fill_color': u'A0C5C7',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'kmac',
#     u'statuses_count': 15564,
#     u'time_zone': u'Sydney',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/PaVJM2FVON',
#     u'utc_offset': 36000,
#     u'verified': True}},
#   u'quoted_status_id': 828177722111168512,
#   u'quoted_status_id_str': u'828177722111168512',
#   u'retweet_count': 5,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'Self-serving conclusions should have a higher bar. https://t.co/GMEeH9fpLt',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 33851,
#    u'follow_request_sent': False,
#    u'followers_count': 210366,
#    u'following': True,
#    u'friends_count': 424,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4798,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14047,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:38:17 +0000 2017',
#   u'entities': {u'hashtags': [{u'indices': [73, 87],
#      u'text': u'SundayScience'}],
#    u'media': [{u'display_url': u'pic.twitter.com/59XSPdLX2O',
#      u'expanded_url': u'https://twitter.com/Rainmaker1973/status/848482709051777024/photo/1',
#      u'id': 848482702869319680,
#      u'id_str': u'848482702869319680',
#      u'indices': [88, 111],
#      u'media_url': u'http://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#      u'sizes': {u'large': {u'h': 800, u'resize': u'fit', u'w': 800},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 848482709051777024,
#      u'source_status_id_str': u'848482709051777024',
#      u'source_user_id': 177101260,
#      u'source_user_id_str': u'177101260',
#      u'type': u'photo',
#      u'url': u'https://t.co/59XSPdLX2O'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 177101260,
#      u'id_str': u'177101260',
#      u'indices': [3, 17],
#      u'name': u'Massimo',
#      u'screen_name': u'Rainmaker1973'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/59XSPdLX2O',
#      u'expanded_url': u'https://twitter.com/Rainmaker1973/status/848482709051777024/photo/1',
#      u'id': 848482702869319680,
#      u'id_str': u'848482702869319680',
#      u'indices': [88, 111],
#      u'media_url': u'http://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#      u'sizes': {u'large': {u'h': 800, u'resize': u'fit', u'w': 800},
#       u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 848482709051777024,
#      u'source_status_id_str': u'848482709051777024',
#      u'source_user_id': 177101260,
#      u'source_user_id_str': u'177101260',
#      u'type': u'animated_gif',
#      u'url': u'https://t.co/59XSPdLX2O',
#      u'video_info': {u'aspect_ratio': [1, 1],
#       u'variants': [{u'bitrate': 0,
#         u'content_type': u'video/mp4',
#         u'url': u'https://video.twimg.com/tweet_video/C8ZqhdaW0AAsONc.mp4'}]}}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855581487227215873,
#   u'id_str': u'855581487227215873',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 1095,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Apr 02 10:30:16 +0000 2017',
#    u'entities': {u'hashtags': [{u'indices': [54, 68],
#       u'text': u'SundayScience'}],
#     u'media': [{u'display_url': u'pic.twitter.com/59XSPdLX2O',
#       u'expanded_url': u'https://twitter.com/Rainmaker1973/status/848482709051777024/photo/1',
#       u'id': 848482702869319680,
#       u'id_str': u'848482702869319680',
#       u'indices': [69, 92],
#       u'media_url': u'http://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#       u'sizes': {u'large': {u'h': 800, u'resize': u'fit', u'w': 800},
#        u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/59XSPdLX2O'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/59XSPdLX2O',
#       u'expanded_url': u'https://twitter.com/Rainmaker1973/status/848482709051777024/photo/1',
#       u'id': 848482702869319680,
#       u'id_str': u'848482702869319680',
#       u'indices': [69, 92],
#       u'media_url': u'http://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/tweet_video_thumb/C8ZqhdaW0AAsONc.jpg',
#       u'sizes': {u'large': {u'h': 800, u'resize': u'fit', u'w': 800},
#        u'medium': {u'h': 600, u'resize': u'fit', u'w': 600},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'animated_gif',
#       u'url': u'https://t.co/59XSPdLX2O',
#       u'video_info': {u'aspect_ratio': [1, 1],
#        u'variants': [{u'bitrate': 0,
#          u'content_type': u'video/mp4',
#          u'url': u'https://video.twimg.com/tweet_video/C8ZqhdaW0AAsONc.mp4'}]}}]},
#    u'favorite_count': 2114,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 848482709051777024,
#    u'id_str': u'848482709051777024',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 1095,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    u'text': u'A very visual demonstration of the area of the sphere\n#SundayScience https://t.co/59XSPdLX2O',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Aug 11 07:13:13 +0000 2010',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Astronomy, space imaging & processing, astronautics, meteorology, #CitizenScience. @AstronautiNEWS columnist (IT). Engineer, #STEM \xbb Science & Space news',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'astratelescope.org',
#         u'expanded_url': u'http://www.astratelescope.org/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/M7lNlCNbHR'}]}},
#     u'favourites_count': 1900,
#     u'follow_request_sent': False,
#     u'followers_count': 14104,
#     u'following': False,
#     u'friends_count': 219,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 177101260,
#     u'id_str': u'177101260',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'it',
#     u'listed_count': 453,
#     u'location': u'Italy, North by Northwest',
#     u'name': u'Massimo',
#     u'notifications': False,
#     u'profile_background_color': u'C6E2EE',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/551781899077574656/fxiMBWHy.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/551781899077574656/fxiMBWHy.jpeg',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/177101260/1422214939',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/686298118904786944/H4aoP8vA_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/686298118904786944/H4aoP8vA_normal.jpg',
#     u'profile_link_color': u'1F98C7',
#     u'profile_sidebar_border_color': u'C6E2EE',
#     u'profile_sidebar_fill_color': u'DAECF4',
#     u'profile_text_color': u'663B12',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Rainmaker1973',
#     u'statuses_count': 70683,
#     u'time_zone': u'Rome',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/M7lNlCNbHR',
#     u'utc_offset': 7200,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @Rainmaker1973: A very visual demonstration of the area of the sphere\n#SundayScience https://t.co/59XSPdLX2O',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 33851,
#    u'follow_request_sent': False,
#    u'followers_count': 210366,
#    u'following': True,
#    u'friends_count': 424,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4798,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14047,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:34:35 +0000 2017',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 113746052,
#      u'id_str': u'113746052',
#      u'indices': [3, 16],
#      u'name': u'Neil Soni',
#      u'screen_name': u'TheRealNeilS'},
#     {u'id': 11740902,
#      u'id_str': u'11740902',
#      u'indices': [43, 52],
#      u'name': u'Tim Ferriss',
#      u'screen_name': u'tferriss'},
#     {u'id': 69317020,
#      u'id_str': u'69317020',
#      u'indices': [58, 71],
#      u'name': u'Jerzy Gregorek',
#      u'screen_name': u'TheHappyBody'},
#     {u'id': 745273,
#      u'id_str': u'745273',
#      u'indices': [76, 82],
#      u'name': u'Naval Ravikant',
#      u'screen_name': u'naval'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855580556997779456,
#   u'id_str': u'855580556997779456',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 4,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Apr 22 00:15:50 +0000 2017',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'itunes.apple.com/us/podcast/the\u2026',
#       u'expanded_url': u'https://itunes.apple.com/us/podcast/the-tim-ferriss-show/id863897795?mt=2&i=1000382685581',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/PDHef4S65k'}],
#     u'user_mentions': [{u'id': 11740902,
#       u'id_str': u'11740902',
#       u'indices': [25, 34],
#       u'name': u'Tim Ferriss',
#       u'screen_name': u'tferriss'},
#      {u'id': 69317020,
#       u'id_str': u'69317020',
#       u'indices': [40, 53],
#       u'name': u'Jerzy Gregorek',
#       u'screen_name': u'TheHappyBody'},
#      {u'id': 745273,
#       u'id_str': u'745273',
#       u'indices': [58, 64],
#       u'name': u'Naval Ravikant',
#       u'screen_name': u'naval'}]},
#    u'favorite_count': 12,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 855575838829551616,
#    u'id_str': u'855575838829551616',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'possibly_sensitive_appealable': False,
#    u'retweet_count': 4,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"Amazing podcast episode: @tferriss with @TheHappyBody and @naval. There's enough wisdom in there to last a lifetime: https://t.co/PDHef4S65k",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Feb 12 22:18:42 +0000 2010',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Building stuff like External Innovation @EsteeLauder and @UnlimitedBrew | Previously @MomTrusted @College_Zen @CMUEngineering | \U0001f4da \u2615\ufe0f \U0001f37b \U0001f3c8 keep me going',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'neilsoni.com',
#         u'expanded_url': u'http://neilsoni.com',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/5LIVU6nZ2p'}]}},
#     u'favourites_count': 13550,
#     u'follow_request_sent': False,
#     u'followers_count': 1529,
#     u'following': False,
#     u'friends_count': 1127,
#     u'geo_enabled': True,
#     u'has_extended_profile': True,
#     u'id': 113746052,
#     u'id_str': u'113746052',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 53,
#     u'location': u'DC/NYC/Nomad',
#     u'name': u'Neil Soni',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/161604075/mqlightsquaresfloralasphalt.br.jpg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/161604075/mqlightsquaresfloralasphalt.br.jpg',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/845671792999989249/W-3KevUc_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/845671792999989249/W-3KevUc_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'TheRealNeilS',
#     u'statuses_count': 7954,
#     u'time_zone': u'Quito',
#     u'translator_type': u'none',
#     u'url': u'https://t.co/5LIVU6nZ2p',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u"RT @TheRealNeilS: Amazing podcast episode: @tferriss with @TheHappyBody and @naval. There's enough wisdom in there to last a lifetime: http\u2026",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 01 23:05:04 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Present',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'farnamstreetblog.com/2017/02/naval-\u2026',
#        u'expanded_url': u'https://www.farnamstreetblog.com/2017/02/naval-ravikant-reading-decision-making/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/VPBBapmlY4'}]}},
#    u'favourites_count': 33851,
#    u'follow_request_sent': False,
#    u'followers_count': 210366,
#    u'following': True,
#    u'friends_count': 424,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 745273,
#    u'id_str': u'745273',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4798,
#    u'location': u'San Francisco, CA',
#    u'name': u'Naval Ravikant',
#    u'notifications': False,
#    u'profile_background_color': u'352726',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/745273/1355705777',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/749155852683055104/0StT9uYS_normal.jpg',
#    u'profile_link_color': u'D02B55',
#    u'profile_sidebar_border_color': u'829D5E',
#    u'profile_sidebar_fill_color': u'99CC33',
#    u'profile_text_color': u'3E4415',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'naval',
#    u'statuses_count': 14047,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/VPBBapmlY4',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sat Apr 22 00:15:09 +0000 2017',
#   u'entities': {u'hashtags': [{u'indices': [90, 101], u'text': u'tcsessions'}],
#    u'media': [{u'display_url': u'pic.twitter.com/373RjGU100',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855575666456223744/photo/1',
#      u'id': 855575663071383554,
#      u'id_str': u'855575663071383554',
#      u'indices': [102, 125],
#      u'media_url': u'http://pbs.twimg.com/media/C9-diFPW0AIgm1j.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C9-diFPW0AIgm1j.jpg',
#      u'sizes': {u'large': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'medium': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'small': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/373RjGU100'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'tcrn.ch/2pLGyci',
#      u'expanded_url': u'http://tcrn.ch/2pLGyci',
#      u'indices': [66, 89],
#      u'url': u'https://t.co/p7H1ooW1bP'}],
#    u'user_mentions': []},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/373RjGU100',
#      u'expanded_url': u'https://twitter.com/TechCrunch/status/855575666456223744/photo/1',
#      u'id': 855575663071383554,
#      u'id_str': u'855575663071383554',
#      u'indices': [102, 125],
#      u'media_url': u'http://pbs.twimg.com/media/C9-diFPW0AIgm1j.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/C9-diFPW0AIgm1j.jpg',
#      u'sizes': {u'large': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'medium': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'small': {u'h': 447, u'resize': u'fit', u'w': 676},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'https://t.co/373RjGU100'}]},
#   u'favorite_count': 10,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 855575666456223744,
#   u'id_str': u'855575666456223744',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'possibly_sensitive_appealable': False,
#   u'retweet_count': 12,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   u'text': u'Uber\u2019s head of diversity will be speaking at TC Sessions: Justice https://t.co/p7H1ooW1bP #tcsessions https://t.co/373RjGU100',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 07 01:27:09 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Breaking technology news, analysis, and opinions from TechCrunch. The number one guide for all things tech. Got a tip? Let us know tips@techcrunch.com',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'techcrunch.com',
#        u'expanded_url': u'http://techcrunch.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/b5Oyx12qGG'}]}},
#    u'favourites_count': 1926,
#    u'follow_request_sent': False,
#    u'followers_count': 8942326,
#    u'following': True,
#    u'friends_count': 903,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 816653,
#    u'id_str': u'816653',
#    u'is_translation_enabled': True,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 108945,
#    u'location': u'San Francisco, CA',
#    u'name': u'TechCrunch',
#    u'notifications': False,
#    u'profile_background_color': u'149500',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/621096023751004161/BAKy7hCT.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/816653/1492704252',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/615392662233808896/EtxjSSKk_normal.jpg',
#    u'profile_link_color': u'097000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'222222',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'TechCrunch',
#    u'statuses_count': 154506,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/b5Oyx12qGG',
#    u'utc_offset': -25200,
#    u'verified': True}}]

# %%
# import request
# import time

type(home_timeline)
# Out:
# str

# %%
type(content)
# Out:
# list
